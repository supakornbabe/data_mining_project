# %%
# !pip install pythainlp

# %%
import matplotlib.pyplot as plt
import pandas as pd
import json
import sys
import os
import pythainlp
from pythainlp.corpus import stopwords
from datetime import datetime
import deepcut
# os.chdir(os.path.join(os.getcwd(), '../data/processed_except'))
os.getcwd()
# Out:
# '/Users/supakornbabe/Social_Networks_Data_Mining/Proj/notebook'

# %%
def read_file(path):
    data = []
    file = open(path, "r")
    count = 0
    for line in file:
        try:
            if (line == '\n'):      # skip empty lines
                continue
            count = count + 1
            data.append(json.loads(line))
            if count % 100 == 0:
                sys.stdout.write('.')
            if count % 7000 == 0:
                sys.stdout.write('\n')
        except Exception as e:
            print(e)
            continue
    print(f"\n{count} line read.")
    df = pd.DataFrame.from_dict(data)
    return df

# %%
def count_word(df):
    words = {}
    count=0
    thai_symbols = 'กขฃคฅฆงจฉชซฌญฎฏฐฑฒณดตถทธนบปผฝพฟภมยรลวศษสหฬอฮฤฦะัาำิีึืุูเแโใไๅ็่้๊๋ฯๆฺ์ํ๎๏๚๛๐๑๒๓๔๕๖๗๘๙฿'
    symbols = "!@#$%^&*()_+=-[]{}\|;:',./<>\"?1234567890qwertyuiopasdfghjklzxcvbnmQWERTYUIOPLKJHGFDSAZXCVBNM"
    thai_stopwords = stopwords.words('thai')
    for title in df['title']:
        count+=1
        print(str(count)+" " + title)
        for word in pythainlp.word_tokenize(title, engine='deepcut', whitespaces=False):
            if word in symbols:
                continue
            if word in thai_stopwords:
                continue
            if word in thai_symbols:
                continue
            if word not in words:
                print(word)
                words[word] = 1
            else:
                print(word)
                words[word] +=1
    dwords = pd.DataFrame(words.items(), columns=['Word', 'Count'])
    dwords.sort_values(by='Count',ascending=False,inplace=True)
    dwords=dwords[dwords.Word != 'quot']
    dwords=dwords[dwords.Word != '...']
    dwords=dwords[dwords.Word != 'นี้']
    dwords=dwords[dwords.Word != '##']
    dwords=dwords[dwords.Word != '###']
    dwords=dwords[dwords.Word != '####']
    dwords=dwords[dwords.Word != '#####']
    dwords.to_csv ('export_dataframe.csv', index = None, header=True)    
    return dwords

# %%
def get_word_count_list(df,start=0,stop=10):
    Counts = df.Count[start:stop]
    Counts = list(Counts)
    
    Words = df.Word[start:stop]
    Words = list(Words)
    return Words,Counts

def plot(x,y):
    print(x)
    print(y)

    width = 0.6
    fig, ax = plt.subplots()
    plt.bar(x, y, width, alpha=1, color='g')

    # Setting axis labels and ticks
    ax.set_ylabel('จำนวณ', fontsize=15)
    ax.set_title('คำที่อยู่ในหัวกระทู้', fontsize=15, fontweight='bold')
    ax.set_xticklabels(x,rotation=90)
    plt.grid()

    #set font
    from matplotlib import rcParams
    rcParams['font.family'] = 'sans-serif'
    rcParams['font.sans-serif'] = ['Tahoma']

    # Figure size
    fig.set_size_inches(18.5, 10.5)
    fig.savefig('word_in_title.png', dpi=80)

# %%
df = read_file('../data/processed_except/all_topic_id_new.csv')
df.date = pd.to_datetime(df.date)
mask = (df['date'] > '2016-06-01') & (df['date'] <= '2016-06-02')
df_BTW_input_date = df.loc[mask]
word_count = count_word(df_BTW_input_date)
word_count.head()
x,y = get_word_count_list(df = word_count,stop=30)
plot(x,y)
# Out:
# ......................................................................
# ......................................................................
# ......................................................................
# ......................................................................
# ......................................................................
# ......................................................................
# ......................................................................
# ......................................................................
# ......................................................................
# ......................................................................
# ......................................................................
# ......................................................................
# ......................................................................
# ......................................................................
# ......................................................................
# ......................................................................
# ......................................................................
# ......................................................................
# ......................................................................
# ......................................................................
# ......................................................................
# ......................................................................
# ......................................................................
# ......................................................................
# ......................................................................
# ......................................................................
# ......................................................................
# ......................................................................
# ......................................................................
# ......................................................................
# ......................................................................
# ......................................................................
# ......................................................................
# ......................................................................
# ......................................................................
# ......................................................................
# ......................................................................
# ......................................................................
# ......................................................................
# ...................
# 274971 line read.
# 1 [CR] ฺBackpack to Switzerland มีเงิน1แสนก็ไม่พอ
# CR
# Backpack
# to
# Switzerland
# เงิน
# แสน
# 2 [CR] A show must see at Siam Niramit Phuket : พาฝรั่งย้อนรอยวิถีชีวิตแบบไทยๆ ที่สยามนิรมิตภูเก็ต
# CR
# show
# must
# see
# at
# Siam
# Niramit
# Phuket
# ฝรั่ง
# ย้อนรอย
# วิถี
# ชีวิต
# ไทย
# สยามนิรมิตภูเก็ต
# 3 ทำไมค่าตั๋วเครื่องบินถูก ทั้งที่ต้นทุนสูงมาก
# ค่า
# ตั๋ว
# เครื่อง
# บิน
# ต้นทุน
# 4 ที่พักหัวหิน แบบมีสระว่ายน้ำ
# พักหัวหิน
# สระ
# ว่ายน้ำ
# 5 [SR] ไปFull moon ยังไงให้ถูก( ฉบับข้อมูล)
# SR
# Full
# moon
# ฉบับ
# ข้อมูล
# 6 ขอสอบถาม เที่ยวฮ่องกงช่วงเดือน กรกฏาคม หน่อยครับ
# สอบถาม
# เที่ยว
# ฮ่องกง
# เดือน
# กรกฏาคม
# 7 อาศัยบ้านญาติต้องทำตัวแบบไหนคะ เครียกมาก
# อาศัย
# บ้าน
# ญาติ
# ทำ
# ตัว
# เครียก
# 8 จริงหรือเปล่าครับ ที่เราอยู่บนเครื่องบิน ความกดอากาศต่ำ ทำให้รับรสชาติอาหารได้แย่ลง
# เปล่า
# เครื่อง
# บิน
# กด
# อากาศ
# ต่ำ
# ทำ
# รสชาติ
# อาหาร
# แย่
# 9 Air Asia X เปิดเส้นทางใหม่ อิหร่าน ท่านใดจะไปบ้างครับ
# Air
# Asia
# เส้นทาง
# อิหร่าน
# ท่าน
# ใด
# 10 สำหรับคนสนเรียนภาษาญี่ปุ่นในเมืองโอซาก้าค่ะ(ฟรี)
# สำหรับ
# คน
# สน
# เรียน
# ภาษา
# ญี่ปุ่น
# เมืองโอซาก้าค่ะ
# ฟรี
# 11 เที่ยวชิวๆที่ไบรตัน Brighton, UK
# เที่ยว
# ชิว
# ไบรตัน
# Brighton
# UK
# 12 สายการบิน British airways เป็นไงบ้าง?
# สาย
# บิน
# British
# airways
# 13 ที่นั่งแถวแรกของ Business Class การบินไทย &gt;&gt; จอทีวีจะเล็กกว่าปกติ เหมือนกรณี Economy ไหมครับ
# นั่ง
# แถว
# Business
# Class
# บินไทย
# gt
# gt
# จอทีวี
# ปกติ
# เหมือน
# กรณี
# Economy
# ไหม
# 14 ไดอารี่ Housekiping ต่างด้าวในต่างแดน Work and travel 2016(WAT)ที่ Panama City beach, Florida, USA ด้วยภาษาที่ไม่แข็งแรง
# ไดอารี่
# Housekiping
# ด้าว
# แดน
# Work
# and
# travel
# 2016
# WAT
# Panama City
# beach
# Florida
# USA
# ภาษา
# แข็งแรง
# 15 [CR] --- exciter ลุยเขาใหญ่ รับฝนแรกของปี 59 ---
# CR
# exciter
# ลุย
# เขาใหญ่
# ฝน
# ปี
# 59
# 16 ใครเคยนั่งรถบัสมินิของ ศรีมงคลทัวร์บ้างจาก ระยอง-กาญจนบุรี ???
# นั่ง
# รถ
# บัสมินิ
# ศรีมงคล
# ทัวร์
# ระยอง
# กาญจนบุรี
# 17 เพื่อนๆคนไหนเคยไปกับทัวร์นี้บ้างครับ
# เพื่อน
# คน
# ทัวร์
# นี้
# 18 [SR] &gt; &gt; teeShutterB &lt; &lt; Japan1stTime . . . Part#1 . . . ไปโดนหลอกที่ญี่ปุ่นนนนน
# SR
# gt
# &gt
# teeShutter
# &lt
# lt
# Japan
# st
# Time
# Part#
# โดน
# หลอก
# ญี่ปุ่น
# นนนน
# 19 เงิน6 เเสนบาท คิดว่าเรียนภาษาที่ต่างประเทศ  กับ เรียนภาษาที่ไทย ผลที่ได้ต่างกันมากมั้ยคะ
# เงิน
# เเสนบาท
# เรียน
# ภาษา
# ประเทศ
# เรียน
# ภาษา
# ไทย
# 20 รบกวนช่วยตรวจแพลนเกาหลีด้วยครับ
# รบกวน
# ตรวจ
# แพลน
# เกาหลี
# 21 สงสัยว่า grab taxi สำหรับคนขับ Taxi ชอบให้ลูกค้าจ่ายบัตรเครดิตไหม
# สงสัย
# grab
# taxi
# สำหรับ
# คน
# ขับ
# Taxi
# ชอบ
# ลูกค้า
# จ่าย
# บัตร
# เครดิต
# ไหม
# 22 ปรึกษารองเท้าใส่ลุยหิมะฮอกไกโด
# ปรึกษา
# รองเท้า
# ใส่
# ลุย
# หิมะ
# ฮอกไกโด
# 23 ไปขับรถเที่ยวกัน เยอรมัน ออสเตรีย เชค - Day 3 Hallstatt
# ขับ
# รถ
# เที่ยว
# เยอรมัน
# ออสเตรีย
# เชค
# Day
# Hallstatt
# 24 [CR] สงบ สุขหัวใจ ที่บ้านมะกอก เกาะกูด
# CR
# สงบ
# สุข
# หัวใจ
# บ้านมะกอก เกาะกูด
# 25 สอบถามผู้ใช้งาน - แผ่นรองนอน quechua
# สอบถาม
# งาน
# แผ่น
# รองนอน
# quechua
# 26 ถ้าไปเวียดนาม ซื้อตั๋วเครื่องบินขาไปเที่ยวเดียวได้ไหมคะ
# เวียดนาม
# ซื้อ
# ตั๋ว
# เครื่อง
# บิน
# ขา
# เที่ยว
# ไหม
# 27 สอบถามวิธีเดินทางเกียวโต อาราชิยาม่า(ป่าไผ่) - ศาลเจ้าฟูชิมิอินาริ -วัดน้ำใส
# สอบถาม
# วิธี
# เดินทาง
# เกียวโต
# อาราชิยาม่า
# ป่า
# ไผ่
# ศาลเจ้าฟูชิมิอินาริ
# วัด
# น้ำใส
# 28 จะไปทำงานที่ตึก sj infinite แถวจตุจักร จอดรถไหนดีคะ
# ทำ
# งาน
# ตึก
# sj
# infinite
# แถว
# จตุจักร
# จอด
# รถ
# ดี
# 29 รบกวนถามเรื่องจะเอารถตู้ไปใช่ที่เกาะช้างค่ะ เห็นบอกว่าไม่อนุญาต
# รบกวน
# ถาม
# เรื่อง
# รถ
# ตู้
# เกาะ
# ช้าง
# อนุญาต
# 30 [CR] สมุย-พะงัน-เต่า 10 คืน ตอนที่.9
# CR
# สมุย
# -พะงัน
# เต่า
# 10
# คืน
# ตอน
# 31 Gift Voucher ที่พักพร้อมอาหารเช้าที่ ภูธาราฟ้า รีสอร์ท จ.นครราชสีมา
# Gift
# Voucher
# พัก
# อาหาร
# เช้า
# ภูธาราฟ้า
# รีสอร์ท
# จ.นครราชสีมา
# 32 สำหรับคนไทยที่โชคดีได้รับเลือกในโครงการ DV-2017
# สำหรับ
# คน
# ไทย
# โชค
# ดี
# เลือก
# โครงการ
# DV
# 2017
# 33 ต้องการเช่าเครื่องบินส่วนตัวไปพม่า
# ต้องการ
# เช่า
# เครื่อง
# บิน
# ตัว
# พม่า
# 34 สอบถามการนั่งรถ Keisei Bus จากสถานีโตเกียว ไป นาริตะ
# สอบถาม
# นั่ง
# รถ
# Keisei
# Bus
# สถานีโตเกียว
# นาริตะ
# 35 ผัดเปรี้ยวหวานกุ้ง สูตรนี้ง่ายใครทำก็อร่อยค่ะ by ครัวตุ๊กตา
# ผัด
# เปรี้ยว
# หวาน
# กุ้ง
# สูตร
# นี้
# ทำ
# อร่อย
# by
# ครัว
# ตุ๊กตา
# 36 เดินทางไปเยี่ยมทหาร ค่ายสมเด็จพระนั่งเกล้า
# เดินทาง
# เยี่ยม
# ทหาร
# ค่ายสมเด็จพระนั่งเกล้า
# 37 สอบถาม เส้นทาง ปากเกร็ด ไป ฟู้ดแลนด์ (ศรีนครินทร์)
# สอบถาม
# เส้นทาง
# ปากเกร็ด
# ฟู้ดแลนด์
# ศรีนครินทร์
# 38 ทำไมสิงคโปร์แอร์ไลน์ถึงไม่ใช้ B787 ซึ่งเป็นเครื่องบินทันสมัยสุดในปัจจุบัน แต่กลับให้บ.ลูก Scoot ใช้และตัวเองใช้ A350 แทน
# สิงคโปร์
# แอร์ไลน์
# 787
# เครื่อง
# บิน
# บ.
# ลูก
# Scoot
# ตัว
# 350
# แทน
# 39 บัตรเดบิต กสิกร จองตั๋ว jetstar
# บัตร
# เดบิต
# กสิกร
# จอง
# ตั๋ว
# jetstar
# 40 [CR] &gt;&gt;&gt;&gt;กาลครั้งหนึ่ง ณ ไต้หวัน ในวันที่ฟ้าครึ้ม&lt;&lt;&lt;&lt;
# CR
# gt
# &gt
# gt
# gt
# กาล
# ไต้หวัน
# ฟ้า
# ครึ้ม
# lt
# lt
# lt
# lt
# 41 สมัครบัตรเสริม กรุงเทพแอร์เอเชีย จะถามว่า
# สมัครบัตร
# เสริม
# กรุงเทพแอร์เอเชีย
# ถาม
# 42 ทำความสะอาด nike max air vapor backpack
# ทำ
# สะอาด
# nike
# max
# air
# vapor
# backpack
# 43 ไป sydney ต้องเตรียมซื้อบัตร pass อะไรที่ช่วยประหยัดในการท่องเที่ยวมั่งคะ
# sydney
# เตรียม
# ซื้อ
# บัตร
# pass
# ประหยัด
# ท่องเที่ยว
# มั่ง
# 44 [CR] ไป &quot;ไทเป&quot; เที่ยวไหนดี??? --- 15 พิกัดน่าเช็คอินในไทเป
# CR
# quot
# ;ไทเป&quot
# เที่ยว
# ดี
# 15
# พิกัด
# เช็ค
# อิน
# ไทเป
# 45 กำลังจะไปเที่ยวเกาะช้างคะ อยากทราบว่ามีร้านอาหารอร่อยๆแนะนำไหมคะ
# เที่ยว
# เกาะ
# ช้าง
# ทราบ
# ร้าน
# อาหาร
# อร่อย
# แนะนำ
# ไหม
# 46 จะไปดูไบต้องใช้อะไรบ้าง ?
# ดู
# ไบ
# 47 [CR] รีวิว Family trip ขับรถเที่ยวนิวซีแลนด์เกาะใต้ 9 วัน 7 คืน ในราคา 6 หมื่น [Part 6/6 From west to east]
# CR
# รีวิว
# Family
# trip
# ขับ
# รถ
# เที่ยว
# นิวซีแลนด์
# เกาะ
# คืน
# ราคา
# หมื่น
# Part
# From
# west
# to
# east
# 48 [CR] เมื่อผมไปขุด (ร่อน) ทอง ที่ ต่างประเทศ
# CR
# ผม
# ขุด
# ร่อน
# ทอง
# ประเทศ
# 49 [CR] รีวิว &quot;ภูนกเงือกรีสอร์ท@กาญจนบุรี&quot; ที่คิดว่าจะประทับใจ แต่ไม่เลย
# CR
# รีวิว
# quot
# ภูนก
# เงือก
# รีสอร์ท@กาญจนบุรี
# quot
# ประทับใจ
# 50 จากสนามบินชุมพรตอนค่ำ (นกแอร์รอบค่ำ) จะมีรถไปท่าเรือเกาะเต่า(ทุ่งมะขามน้อยมั้ยครับ)
# สนามบินชุมพร
# ตอน
# ค่ำ
# นกแอร์
# รอบ
# ค่ำ
# รถ
# ท่า
# เรือเกาะเต่า
# ทุ่งมะขามน้อย
# 51 ขอคำปรึกษาเรื่องการซื้อพาสเที่ยวแถบคันไซหน่อย
# ปรึกษา
# เรื่อง
# ซื้อ
# พาส
# เที่ยว
# แถบ
# คันไซหน่อย
# 52 ถ้าที่นั่งบนเครื่องบินว่าง จะนั่งตรงไหนก็ได้เหรอ (Quite Zone หรือ Business Class)
# ที่นั่ง
# เครื่อง
# บิน
# ว่าง
# นั่ง
# เหรอ
# Quite
# Zone
# Business
# Class
# 53 [SR] Kyotango เคียวทังโกะเมืองทะเลแห่งเกียวโต
# SR
# Kyotango
# เคียว
# ทัง
# โกะ
# เมือง
# ทะเล
# เกียวโต
# 54 [CR] หนีร้อนไปนอนเขา(ใหญ่) @โบทานิกา เขาใหญ่ รีสอร์ท
# CR
# หนี
# ร้อน
# นอน
# โบทานิกา
# รีสอร์ท
# 55 การใช้ชีวิตในนิวยอร์ก อเมริกา ผ่านรายการ เจอนั่นเจอนี่
# ชีวิต
# นิวยอร์ก อเมริกา
# รายการ
# เจอ
# เจอ
# 56 [CR] Sri Lankan Airlines Economy from Bangkok(BKK) to Colombo(CMB) ฉบับกระทัดรัด
# CR
# Sri Lankan Airlines Economy
# from
# Bangkok
# BKK
# to
# Colombo
# CMB
# ฉบับ
# กระทัดรัด
# 57 เที่ยวม.ราม-วัดอรุณ
# เที่ยว
# ม.
# ราม
# วัดอรุณ
# 58 มีใครไปเที่ยวต่างประเทศแล้วสะพายกระเป๋าmessenger bag ติดตัวบ้าง
# เที่ยว
# ประเทศ
# สะพาย
# กระเป๋า
# messenger
# bag
# ติด
# ตัว
# 59 รบกวนถามเรื่องการเปลี่ยนเครื่องที่ Chicago (O'Hare International Airport )ค่ะ
# รบกวน
# ถาม
# เรื่อง
# เครื่อง
# Chicago
# Hare
# International
# Airport
# 60 ทะเลนครศรีธรรมราช มีที่ไหนน่าเที่ยวบ้าง ขอแบบทริปประหยัด
# ทะเล
# นครศรีธรรมราช
# เที่ยว
# ทริป
# ประหยัด
# 61 ไปเกาหลีรอบแรกติดตม. ไปรอบสองจะผ่านไหม??
# เกาหลี
# รอบ
# ติดตม.
# รอบ
# สอง
# ไหม
# 62 ทัวร์ญี่ปุ่น ระหว่าง3บริษัทนี้ บริษัทไหนบริการดีที่สุดคะ?
# ทัวร์
# ญี่ปุ่น
# บริษัท
# นี้
# บริษัท
# บริการ
# ดี
# 63 ช่วยแนะนำ airbnb ในสิงค์โปร์ ที่ใกล้ MRT และราคาไม่แพงหน่อยค่ะ
# แนะนำ
# airbnb
# สิงค์โปร์
# MRT
# ราคา
# แพง
# 64 เลือกเรียนต่อด้าน Supply chain ที่ไหนดีกว่าคะ
# เลือก
# เรียน
# Supply
# chain
# ดี
# 65 [CR] รีวิวห้อง Studio Executive , Citadines Sukhumvit 16 Bangkok
# CR
# รีวิว
# ห้อง
# Studio
# Executive
# Citadines
# Sukhumvit
# 16
# Bangkok
# 66 เที่ยวฮ่องกงครั้งแรก ขอคำแนะนำเรื่องโรงแรมครับ
# เที่ยว
# ฮ่องกง
# แนะนำ
# เรื่อง
# โรง
# แรม
# 67 [CR] - - - [KALONGPHONGINJAPAN] BEPPU+KITSUKI ในวันพายุเข้า (PAGE4) - - -
# CR
# KALONGPHONGINJAPAN
# BEPPU+
# KITSUKI
# พายุ
# PAGE
# 68 เอายาไปอังกฤษ
# ยา
# อังกฤษ
# 69 แม่สลอง...มายเพลส vs แม่สลองเมาเท่นโฮม
# แม่
# สลอง
# ...
# มายเพลส
# vs
# แม่
# สลอง
# เมา
# เท่น
# โฮม
# 70 จากปากน้ำ สมุทรปราการ ไป ตลาดไท 1 ชม.ได้มั้ย
# ปาก
# น้ำ
# สมุทรปราการ
# ตลาด
# ไท
# ชม.
# 71 [CR] Review : Hanoi, Halong Bay, Hoa lu Tam coc (Ninh Binh) 19-23/05/2016 ด้วยตนเอง ฉบับครอบครัว
# CR
# Review
# Hanoi
# Halong
# Bay
# Hoa
# lu
# Tam
# coc
# Ninh
# Binh
# 19
# 05
# 2016
# ฉบับ
# ครอบครัว
# 72 ขอความช่วยเหลือค่ะ!!! กำลังมึนงงกับเอกสารขอวีซ่าเชงเก้นไปฝรั่งเศส
# ช่วยเหลือ
# มึนงง
# เอกสาร
# วีซ่า
# เชง
# เก้น
# ฝรั่งเศส
# 73 ช่วยด้วยค่ะสอบถามการเดินทางกัวลาลัมเปอร์
# สอบถาม
# เดินทาง
# กัวลาลัมเปอร์
# 74 ขอสอบถามการเดินทางจากสนามบินอินชอน (ICN) ไปย่านเมียงดง (Myeongdong) หน่อยครับ
# สอบถาม
# เดินทาง
# สนามบินอินชอน
# ICN
# ย่าน
# เมียงดง
# Myeongdong
# 75 สอบถามสายรถเมล์หรือรถตู้จาก รร.นายร้อยสามพรานไปเซ็นทรัลศาลายา ต้องขึ้นสายไหนคะ
# สอบถาม
# สาย
# รถ
# เมล์
# รถ
# ตู้
# รร.
# นายร้อยสามพราน
# เซ็นทรัลศาลายา
# สาย
# 76 [CR] ลุยเดี่ยวเที่ยวตัวเมืองเชียงใหม่-แม่กำปอง ไปรถไฟ กลับรถทัวร์ ตะลุยมั่วมั่วด้วยมอเตอร์ไซค์
# CR
# ลุย
# เดี่ยว
# เที่ยว
# ตัวเมือง
# เชียงใหม่
# แม่
# กำปอง
# รถไฟ
# รถ
# ทัวร์
# ตะลุย
# มั่วมั่ว
# มอเตอร์ไซค์
# 77 เรียนจบตรีแล้ว อยากหาทุนไปเรียนตรีอีกใบที่ต่างประเทศ
# เรียน
# จบ
# ตรี
# หา
# ทุน
# เรียน
# ตรี
# ใบ
# ประเทศ
# 78 มาระลึกความหลังกับละครซิทคอมจากอเมริกาในช่วง 70,80 และ 90 ว่าชอบเรื่องไหนกันบ้าง?
# ระลึก
# ละคร
# ซิทคอม
# อเมริกา
# 70
# 80
# ชอบ
# เรื่อง
# 79 สายการบินคาเธ่ย์แปซิฟิคเป็นผู้ให้บริการเครื่องบินแอร์บัส เอ350 เอ็กซ์ดับเบิลยูบี รายใหม่
# สาย
# บินคาเธ่ย์แปซิฟิค
# บริการ
# เครื่อง
# บิน
# แอร์บัส
# เอ
# 350
# เอ็กซ์ดับเบิลยูบี
# 80 สภาพอากาศหลวงพระบาง
# สภาพ
# อากาศ
# หลวงพระบาง
# 81 [CR] เที่ยว พัด-ตะ-ลุง หรอย แรง ^^
# CR
# เที่ยว
# พัด
# ตะ
# ลุง
# หรอย
# แรง
# 82 สบายดี ... วังเวียง DAY 1~~~
# สบายดี
# ...
# วังเวียง
# DAY
# ~
# ~
# ~
# 83 ใครพอรู้จากเดอะมอลล์งามวงศ์วานไปเซ็นทรัลเฟสติวัล อีสต์วิลล์ ต้องนั่งตรงไหน
# รู้จาก
# เดอะมอลล์งามวงศ์วาน
# ไปเซ็นทรัลเฟสติวัล
# อีสต์วิลล์
# นั่ง
# 84 Scoot สกู๊ต ดอนเมือง-โอซาก้า ณ.ตอนนี้ยังมี over booking อยู่หรือเปล่าครับ
# Scoot
# สกู๊ต
# ดอนเมือง
# -โอซาก้า
# ณ.ตอน
# นี้
# over
# booking
# เปล่า
# 85 ท่าเรือยอดพิมาน จอดรถที่ไหนครับ
# ท่าเรือยอด
# พิมาน
# จอด
# รถ
# 86 Superrich สาขา RDR VBD JTC นี่คือสาขาอะไรครับ
# Superrich
# สาขา
# RDR VBD
# JTC
# สาขา
# 87 [CR] รีวิวขับรถเที่ยวตะลุยคันไซ@วันที่ 3 Rinku Premiun Outlets
# CR
# รีวิว
# ขับ
# รถ
# เที่ยว
# ตะลุย
# คันไซ@วัน
# Rinku
# Premiun
# Outlets
# 88 ช่วงนี้เห็นกระทู้ถามเรื่องขออาศัยบ้านคนอื่นเวลาไปอยู่เมืองนอกแล้วลำบากใจ ทำไมตอนขอมาอาศัย คนขอไม่คิดถึงผลเสียกันบ้าง?
# นี้
# กระทู้
# ถาม
# เรื่อง
# อาศัย
# บ้าน
# คน
# เวลา
# เมือง
# ลำบากใจ
# ตอน
# อาศัย
# คน
# 89 [CR] ::เมื่อปรมาจารย์สายหอย:::มาบุก::{บ้านบุฟเฟ่หอย วังใหญ่โฮมสเตย์}
# CR
# ปร
# มาจารย์
# สายหอย
# มาบุก
# บ้าน
# บุฟเฟ่หอย
# วังใหญ่โฮมสเตย์
# 90 อยากทราบโรงเรียนหญิงล้วนที่เกาหลีค่ะ
# ทราบ
# โรง
# เรียน
# หญิง
# เกาหลี
# 91 [CR] &quot;TOKYO-KAWAGUSHIGO-NIKKO&quot; 04 – 10 FEBUARY 2016
# CR
# quot
# TOKYO-KAWAGUSHIGO-
# NIKKO&quot
# 04
# –
# 10
# FEBUARY
# 2016
# 92 ซื้อเต้นท์ทางเนท ได้ของมีตำหนิ .......... ผู้ขายไม่รับผิดชอบ T T
# ซื้อ
# เต้นท์
# เนท
# ตำหนิ
# ..........
# ขาย
# รับผิดชอบ
# 93 [CR] Review Baan i talay sea view
# CR
# Review
# Baan
# talay
# sea
# view
# 94 [CR] -+ Pokemon Cafe ! Gotta catch 'em all !! มาตามกินเหล่าโปเกมอนกันเถอะ ! +-
# CR
# Pokemon
# Cafe
# Gotta
# catch
# em
# all
# กิน
# โปเก
# มอน
# 95 ใครรู้วิธีเดินทางจาก ลพบุรี ไป อุบล บ้างครับ จะไปบวชครับ (ผมไม่มีรถนะครับ มีเงินอยู่ พอขึ้นรถประจำทางได้ รถตู้ได้ )
# รู้
# วิธี
# เดินทาง
# ลพบุรี
# อุบล
# บวช
# ผม
# รถ
# เงิน
# รถ
# ประจำ
# รถ
# ตู้
# 96 [CR] New Zealand (เกาะเหนือ-เกาะใต้ ... เกาะใต้-เกาะเหนือ)
# CR
# New
# Zealand
# เกาะ
# เหนือ
# เกาะ
# ...
# เกาะใต้
# เกาะเหนือ
# 97 ไปสิงคโปร์ ใช้ซิม singtel หรือ starhub ดี
# สิงคโปร์
# ซิม
# singtel
# starhub
# ดี
# 98 ขอคำแนะนำหาที่พัก ใกล้ๆ มสธ. หน่อยได้ไหมค่ะ พอดีต้องไปปฐมนิเทศ ช่วง ต้นๆสิงหานี้อ่ะค่ะ
# แนะนำ
# หา
# พัก
# มสธ.
# ไหม
# ปฐมนิเทศ
# ต้น
# สิงหา
# นี้
# อ่ะ
# 99 2วัน1คืนในพม่า ไปที่ไหนได้บ้าง
# คืน
# พม่า
# 100 ทำไมแอร์บนเครื่องบินไม่ค่อยเย็น?
# แอร์บน
# เครื่อง
# บิน
# เย็น
# 101 ภาษาญี่ปุ่น ตัวฮิรางานะ ตัว  ふ (fu) เขียนอย่างไรให้สวยครับ เขียนทีไรมันกลายเป็นตัวอะไรไม่รู้ทุกที
# ภาษา
# ญี่ปุ่น
# ตัว
# ฮิรางานะ
# ตัว
# ふ
# fu
# สวย
# กลาย
# ตัว
# รู้
# 102 กดโควต้าWork and Holiday นิวซีแลนด์ 2019 เข้ามาคุยกัน
# กด
# โควต้า
# Work
# and
# Holiday
# นิวซีแลนด์
# 2019
# คุย
# 103 เซนทรัลพระราม2ไปซีคอนบางแคไงอ่าครับ
# เซนทรัลพระราม2ไป
# ซี
# คอนบาง
# แคไง
# อ่า
# 104 พลาดท่าให้กับ Pre-Wedding หลักแสน ที่ได้กลับมาคือความแค้น แต่ก็สุดแสนจะประทับใจ
# พลาด
# ท่า
# Pre
# Wedding
# หลัก
# แสน
# แค้น
# แสน
# ประทับใจ
# 105 garmin 2016.20 มีอัพเดท ใช้รุ่น 215w
# garmin
# 2016
# 20
# อัพเดท
# รุ่น
# 215
# 106 [CR] รีวิว ครั้งหนึ่งในชีวิต ที่เรา(แม่ ลูก)คือผู้พิชิตภูกระดึง
# CR
# รีวิว
# ชีวิต
# แม่
# ลูก
# พิชิตภูกระดึง
# 107 สอบถามเรื่องขอวีซ่าเชงเก้นเยอรมันค่ะ
# สอบถาม
# เรื่อง
# วีซ่า
# เชง
# เก้น
# เยอรมัน
# 108 [CR] &quot;เพียงเพื่อนพาเที่ยว&quot; PART 2 ล่องเรือสำราญหมู่เกาะอังกฤษ กับ Princess Cruises เที่ยว Stonehenge &amp; ขึ้นเรือวันแรก
# CR
# quot
# เพื่อน
# เที่ยว
# quot
# PART
# ล่อง
# เรือ
# สำราญ
# หมู่
# เกาะอังกฤษ
# Princess
# Cruises
# เที่ยว
# Stonehenge
# &amp
# เรือ
# 109 [CR] ชะนีเดี่ยวตะลุยดูบอลคนเดียวที่Manchester แล้วเผลอดูเทนนิสต่อที่Madrid ภารกิจทำ2วีซ่าให้ผ่านใน1เดือนเริ่มต้น!!
# CR
# ชะนี
# เดี่ยว
# ตะลุย
# ดูบอล
# คน
# Manchester
# เผลอ
# ดู
# เทนนิส
# Madrid
# ภารกิจ
# ทำ
# วี
# ซ่า
# เดือน
# เริ่มต้น
# 110 จะใช้คูปองบัตร BBL AirAsia โหลดกระเป๋า จะต้องเช็คอินหน้าเคาน์เตอร์หรือว่าทำ online เช็คอินแล้วค่อยยื่นบัตรได้ไหมคะ
# คู
# ปองบัตร
# BBL
# AirAsia
# โหลด
# กระเป๋า
# เช็ค
# อินหน้า
# เคาน์เตอร์
# ทำ
# online
# เช็ค
# อิน
# ยื่น
# บัตร
# ไหม
# 111 [CR] My Only Sunshine @ Sunshine Paradise Resort
# CR
# My
# Only
# Sunshine
# Sunshine
# Paradise
# Resort
# 112 [CR] รีวิว ทริปลุยเดี่ยว เที่ยวKagawa...จังหวัดที่เล็กที่สุดของญี่ปุ่น 10วัน9คืน ค่ะ ;) &lt;Part 3-Shodoshima&amp;Takamatsu&gt;
# CR
# รีวิว
# ทริปลุย
# เดี่ยว
# เที่ยว
# Kagawa
# ...
# จังหวัด
# ญี่ปุ่น
# 10
# คืน
# lt
# Part
# Shodoshima&amp;Takamatsu&gt
# 113 นครปฐม แถวพระปฐมเจดีย์มีรถตู้มากรุงเทพไหมคะ
# นครปฐม
# แถว
# พระปฐมเจดีย์
# รถ
# ตู้
# กรุงเทพไหม
# 114 เพื่อปลูกฝังให้อนุรักษ์สิ่งแวดล้อม
# ปลูกฝัง
# อนุรักษ์
# สิ่งแวดล้อม
# 115 ลุยเดี่ยวหาข้าวมันไก่เบตง กับ CB500F
# ลุย
# เดี่ยว
# หา
# ข้าว
# ไก่
# เบตง
# CB500F
# 116 scuba โลซิน-เกาะเต๋า liveaboard (เยือนโลซินถิ่นฉลามวาฬ แวะเกาะเต๋าหาน้องต่าย)
# scuba
# โลซิน
# เกาะเต๋า
# liveaboard
# เยือน
# โลซินถิ่น
# ฉลามวาฬ
# แวะเกาะเต๋า
# หา
# น้องต่าย
# 117 ถามเส้นทางไปตึกเอ็มไพร์ทาวเวอร์2 ถนนสาทรใต้
# ถาม
# เส้นทาง
# ตึกเอ็มไพร์ทาวเวอร์
# ถนนสาทรใต้
# 118 ทำไมคนขับ Taxi ถึงรู้เส้นทางในกรุงเทพฯเป็นอย่างดี ทั้งๆที่เป็นคนต่างจังหวัด
# คน
# ขับ
# Taxi
# รู้
# เส้นทาง
# กรุงเทพฯ
# ดี
# ทั้งๆที่
# คน
# จังหวัด
# 119 อยากสอบถามการเดินทางไปอาคาร Thai summit ถนนเพชรบุรีตัดใหม่ จากพระราม2หน่อยครับ
# สอบถาม
# เดินทาง
# อาคาร
# Thai
# summit
# ถนนเพชรบุรี
# ตัด
# พระราม2
# 120 สอบเข้า ม.4 วัฒโนทัยพายัพ [มีคำถาม?]
# สอบ
# ม.
# วัฒโนทัย
# พายัพ
# ถาม
# 121 สอบถามเพื่อนๆที่อยู่ในประเทศอังกฤษเรื่อง &quot;สบู่ฮาโรเกต (Harrogate Soap)&quot; ค่ะ
# สอบถาม
# เพื่อน
# ประเทศอังกฤษ
# เรื่อง
# quot
# สบู่ฮาโรเกต
# Harrogate Soap
# quot
# 122 ขาย Voucher Best Western Patong Beach , Phuket   (เบสท์ เวสเทิร์น ป่าตอง บีช โฮเต็ล)
# ขาย
# Voucher
# Best
# Western
# Patong
# Beach
# Phuket
# เบสท์ เวสเทิร์น
# ป่าตอง
# บีช โฮเต็ล
# 123 Voucher Hop Inn คูปอง โรงแรม ฮ็อป อินน์ 450 บาท
# Voucher
# Hop
# Inn
# คู
# ปอง
# โรงแรม ฮ็อป
# อินน์
# 450
# บาท
# 124 [CR] Review เดินป่าเขาหลวง... เส้นทางน้ำตกคลองพวย-น้ำตกนิรนามคลองดินแดง
# CR
# Review
# เดิน
# ป่าเขาหลวง
# ...
# เส้นทาง
# น้ำตกคลอง
# พวย
# น้ำ
# ตก
# นิรนาม
# คลองดินแดง
# 125 ทำไมพวกเด็กนักเรียนนอกถึงหยิ่งจัง
# เด็ก
# เรียน
# หยิ่งจัง
# 126 ขาย Voucher Ibis Bangkok Riverside ไอบิส กรุงเทพฯ ริเวอร์ไซด์
# ขาย
# Voucher
# Ibis
# Bangkok
# Riverside
# ไอบิส
# กรุงเทพฯ
# ริเวอร์ไซด์
# 127 ขอวิธีการเดินทางใน Melbourne และการใช้ซิมโทรศัพท์
# วิธี
# เดินทาง
# Melbourne
# ซิม
# โทรศัพท์
# 128 สอบถามรถตู้จากหัวหินไปอ่าวมะนาวครับบ
# สอบถาม
# รถ
# ตู้
# หัวหิน
# อ่าวมะนาว
# 129 ปรึกษาการเรียน Diploma ที่ New zealand ทีครับ
# ปรึกษา
# เรียน
# Diploma
# New
# zealand
# 130 ไปแตะขอบฟ้าที่แคลิฟอร์เนีย
# แตะ
# ขอบ
# ฟ้า
# แคลิฟอร์เนีย
# 131 ถามเรื่อง one day pass ของ fu ji q กับ thomas land ครับ
# ถาม
# เรื่อง
# one
# day
# pass
# fu
# ji
# thomas
# land
# 132 Loughborough University แนะนำทีค่ะ
# Loughborough University
# แนะนำ
# 133 สอบถามเรื่องซื้อทัวร์ของ DMZ เกาหลีค่ะ
# สอบถาม
# เรื่อง
# ซื้อ
# ทัวร์
# DMZ
# เกาหลี
# 134 [CR] แนะนำที่เที่ยว สะบายดี ที่นี่ หลวงพระบาง
# CR
# แนะนำ
# เที่ยว
# สะบายดี
# หลวงพระบาง
# 135 กรอกแบบฟอร์มการฉีดวัคซีน ไปเรียนต่อที่ อเมริกา ต้องทำยังไงบ้างครับ
# กรอก
# ฟอร์ม
# ฉีด
# วัคซีน
# เรียน
# อเมริกา
# ทำ
# 136 เรียนภาษาเยอรมันให้ได้B1ควรเรียนที่ไหน
# เรียน
# ภาษา
# เยอรมัน
# เรียน
# 137 ถามคนที่เคยไปออสเตรีย ฮังการี เชค สโลวาเกีย หรือคนไทยที่อาศัยอยู่
# ถาม
# คน
# ออสเตรีย
# ฮังการี
# เชค สโลวาเกีย
# คน
# ไทย
# อาศัย
# 138 ใครพอทราบบ้างโรงแรมนี้อยู่ไหนคะ น่าจะแถวปราณบุรีอ่ะค่ะถ้าจำไม่ผิด?
# ทราบ
# โรง
# แรม
# นี้
# แถว
# ปราณบุรี
# อ่ะ
# ['CR', 'เที่ยว', 'รถ', 'สอบถาม', 'เรียน', 'คน', 'เรื่อง', 'บิน', 'เครื่อง', 'ถาม', 'ทำ', 'ไหม', 'ตัว', 'ดี', 'เดินทาง', 'lt', 'gt', 'ภาษา', 'รีวิว', 'แนะนำ', 'ญี่ปุ่น', 'นั่ง', 'ขับ', 'ทัวร์', 'เส้นทาง', 'เกาะ', 'ตู้', 'ซื้อ', 'เกาหลี', 'ลุย']
# [30, 19, 17, 13, 12, 11, 10, 9, 9, 8, 8, 7, 7, 7, 7, 6, 6, 6, 6, 6, 5, 5, 5, 5, 5, 5, 5, 5, 4, 4]
