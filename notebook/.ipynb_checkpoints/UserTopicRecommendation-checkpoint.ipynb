# %%
import os
import numpy as np
import networkx as nx
import matplotlib.pyplot as plt
import pandas as pd

# %matplotlib inline

# %% [markdown]
# # Import Graph Data

# %%
from pathlib import Path

path = Path('../data/processed_except/user_topic_filtered.csv').resolve();
di_graph = nx.DiGraph()
user_set = set()
with open(path, 'r') as input_file:
    # skip first line
    line = input_file.readline().rstrip()
    while True:
        line = input_file.readline().rstrip()

        # EOF
        if line == '':
            break

        splits = line.split(',')
        # prevent self-loop
        if splits[0] != splits[1]:
            user_set.add(splits[1])
            di_graph.add_edge(splits[1], splits[0])

# %%
# edge_df = pd.DataFrame(columns=[ 'Source','Destination' ])
# for index, edge in enumerate(di_graph.edges()):
#     (src, dest) = edge
#     edge_df.loc[index] = [ src, dest ]
# edge_df.head()

# %%
user_pairs = []
user_list = list(user_set)
for x in range(len(user_list)):
    for y in range(x + 1, len(user_list)):
        user_pairs.append((user_list[x], user_list[y]))

# %% [markdown]
# # Jaccard's Coefficient

# %%
un_graph = di_graph.to_undirected()

jaccard_result = []
for pair in user_pairs:
    u = pair[0]
    v = pair[1]
    u_set = set(nx.all_neighbors(un_graph, u))
    v_set = set(nx.all_neighbors(un_graph, v))
    uv_com_set = u_set.intersection(v_set)
    uv_un_set = u_set.union(v_set)
    jaccard_coef = 0
    if len(uv_un_set) > 0:
        jaccard_coef = len(uv_com_set) / len(uv_un_set)
    if jaccard_coef > 0:
        jaccard_result.append((u, v, jaccard_coef))

# %%
jaccard_result = sorted(jaccard_result, key=lambda x: x[2], reverse=True)

# %% [markdown]
# # Result

# %%
flitered_jaccard_result = list(filter(lambda x: x [2] >= 0.5, jaccard_result))

# %%
user_topics_result = {}
for data in flitered_jaccard_result:
    u = data[0]
    v = data[1]
    if u not in user_topics_result:
        user_topics_result[u] = set()
    if v not in user_topics_result:
        user_topics_result[v] = set()
        
    u_set = set(nx.all_neighbors(un_graph, u))
    v_set = set(nx.all_neighbors(un_graph, v))
    uv_com_set = u_set.intersection(v_set)
    uv_un_set = u_set.union(v_set)
    
    un_dif_com = uv_un_set.difference(uv_com_set)
    user_topics_result[u] = user_topics_result[u].union(un_dif_com.difference(u_set))
    user_topics_result[v] = user_topics_result[v].union(un_dif_com.difference(v_set))

# %%
result_df = pd.DataFrame(columns=[ 'User', 'Prediction Topic' ])
for index, utr in enumerate(user_topics_result):
    result_df.loc[index] = [ utr, list(user_topics_result[utr]) ]
result_df.head(50)
# Out:
#                     User                                   Prediction Topic
# 0     oh2radjylBPW4Vduxt                                         [37700048]
# 1    olteszesbBJkh3g5q3j                                         [36894667]
# 2    pb8oxl3b5QQdNjSQD0D  [38179746, 38180028, 38167459, 38180612, 38177...
# 3    oborxz90uMoIfuZQyvj  [38181846, 38179746, 38180028, 38181711, 38178...
# 4    ozevb32vj5xsix6R3Ze                                         [36136603]
# 5     p363sjr6mdU7oi8LH8           [31177339, 36245659, 35108592, 30769364]
# 6   pgs5xc4l1w0koWc444Jv           [36583753, 31879007, 31440005, 36366065]
# 7   ozt5ze11ajWJAJYxtdfa                                         [30102456]
# 8   pgwckg3pd3zRh341PPIi                     [38166121, 36386170, 38166177]
# 9    nkjl6j972BZq5RO2LRp                               [36531498, 33329584]
# 10   n5s9j7qbgrs23JMxpuK  [38186028, 38169087, 38176339, 38180362, 38145...
# 11   pfc1darm6XirR0T9NQw  [38175922, 38178126, 38176339, 38179103, 38180...
# 12   payshh5nzI9CpU3BHSJ  [35593464, 36687711, 37957013, 34206190, 35476...
# 13   oy47yq5bwhLE9qt4db7                                         [37065460]
# 14   pbw6y94e8vflP40RdDh  [38181846, 38169087, 38176339, 38180362, 38180...
# 15   pgu81n4emOQp8RysdkF           [38172159, 38172968, 38179553, 38180388]
# 16   op8zb1sb7xD6x9h0CYd  [30079232, 31107325, 35724927, 35404600, 35417...
# 17   ogzhza7jhJsdoEWgcVj                               [35398887, 36796687]
# 18   o5n08qnciS6ipQsdNj0  [38175922, 38169087, 38178126, 38178979, 38180...
# 19  pgu9hn8rv4gLb7l5icVc  [38169087, 38176339, 38180362, 38178126, 38179...
# 20   oa6p9saaa57rU7R7BNB           [30900667, 31123126, 30447257, 36819746]
# 21   pgxtfaltyDEVEQiWuE9                               [37362428, 37473184]
# 22   p68cbr5s4gbvdQcm8GE                               [33917833, 30567962]
# 23   o8890elgsdPTuhxVeg5           [34105336, 30549082, 30052188, 34196282]
# 24   p7wi3z78aelLCJP9hTM                               [38182716, 38180747]
# 25   pfhjwo7bvZaYj9sW72g  [38175954, 38178773, 30881524, 31393022, 38178...
# 26   orqv4rdi2htSxjMaXC4  [34561163, 34243779, 37063341, 36325751, 35212...
# 27   oglaj8pez8LCPttnkWx  [37458060, 34705411, 37667019, 34004412, 31152...
# 28   oyenwdox0qTZBiaVI2O  [38181846, 38178875, 38180362, 38180017, 38181...
# 29   pgseyg4vaM5Vc9hVzoz                     [38178100, 38179553, 38180035]
# 30  pgtnkw5zgaK4T8IXHFij  [38184525, 38183998, 38178979, 38180362, 38185...
# 31   pedgjp9peW1Z0IjLSIY  [38177555, 38178979, 38180035, 38178126, 38180...
# 32   oem6s9ngfK5n5MiIzuL                     [38179103, 38180018, 38180388]
# 33   osar6wjvhRShE7rtA92           [38178165, 38178954, 38176352, 38178126]
# 34   o4yjwene09m52ZkAHcR                     [37845992, 36643695, 37846201]
# 35   p7oigttv4h9eOXFA6B4           [35268010, 36122948, 33206284, 32780359]
# 36  pgr4lm10n2P8x37CCWkI           [35908486, 31320066, 35966962, 33355512]
# 37   oudlqm3900PQNwV0sEe                     [33179333, 34676172, 35676394]
# 38   pbj2fzhexBlefLxC1oJ  [33094742, 35578948, 34544560, 34171610, 36126...
# 39   moj3sme6afoxfM8XykO                     [31026649, 35574047, 37935031]
# 40   pegr0iiaeKJ3wgGrTNx           [38172159, 38178134, 38176099, 38178165]
# 41   oygj2sb7rEBCidFicUT                     [38164858, 38166122, 38176339]
# 42   pgtq1f9bf6ADubVtRyY           [38176099, 33138565, 37484023, 38175802]
# 43   pel1eiia4mWyZH3OhPB                     [36337931, 34959221, 37570864]
# 44   pdvmo0i5i0M1RMeMtBA                     [36325822, 34860478, 32420006]
# 45   ojlxa79piTfaWVoCc1v           [32982531, 32867353, 32709156, 36143399]
# 46   pfwwsyqzk8hc7cywETP                               [38124662, 38140936]
# 47   pfkjrxovaKsUANgQ3Iu  [36244139, 37502056, 35283155, 30693844, 34310...
# 48   p0l4rw5kleX45NUzz31                     [35283039, 36625017, 32780359]
# 49   nway623lqvY94RhQpCO           [35740015, 32928646, 35268010, 33558788]
